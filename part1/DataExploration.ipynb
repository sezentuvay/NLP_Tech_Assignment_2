# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
# variables
path_train = '../data/input/srl_univprop_en.train.conll'
path_dev   = '../data/input/srl_univprop_en.dev.conll'
path_example   = '../data/input/srl_univprop_en.example.conll'

# %%
# first exploration
c = 0
with open(path_train) as file:
    for line in file:
        print(line)
        c += 1
        
        if c >= 10:
            break
# Out:
# # newdoc id = weblog-juancole.com_juancole_20051126063000_ENG_20051126_063000
#
# # sent_id = weblog-juancole.com_juancole_20051126063000_ENG_20051126_063000-0001
#
# # text = Al-Zaman : American forces killed Shaikh Abdullah al-Ani, the preacher at the mosque in the town of Qaim, near the Syrian border.
#
# 1	Al	Al	PROPN	NNP	Number=Sing	0	root	0:root	SpaceAfter=No	_	_
#
# 2	-	-	PUNCT	HYPH	_	1	punct	1:punct	SpaceAfter=No	_	_
#
# 3	Zaman	Zaman	PROPN	NNP	Number=Sing	1	flat	1:flat	_	_	_
#
# 4	:	:	PUNCT	:	_	1	punct	1:punct	_	_	_
#
# 5	American	american	ADJ	JJ	Degree=Pos	6	amod	6:amod	_	_	_
#
# 6	forces	force	NOUN	NNS	Number=Plur	7	nsubj	7:nsubj	_	_	ARG0
#
# 7	killed	kill	VERB	VBD	Mood=Ind|Tense=Past|VerbForm=Fin	1	parataxis	1:parataxis	_	kill.01	V

# %% [markdown]
# ## Conll Description
#
# "Sentences consist of one or more word lines, and word lines contain the following fields:
#
# ID: Word index, integer starting at 1 for each new sentence; may be a range for multiword tokens; may be a decimal number for empty nodes (decimal numbers can be lower than 1 but must be greater than 0). <br>
# FORM: Word form or punctuation symbol. <br>
# LEMMA: Lemma or stem of word form. <br>
# UPOS: Universal part-of-speech tag. <br>
# XPOS: Language-specific part-of-speech tag; underscore if not available. <br>
# FEATS: List of morphological features from the universal feature inventory or from a defined language-specific extension; underscore if not available. <br>
# HEAD: Head of the current word, which is either a value of ID or zero (0). <br>
# DEPREL: Universal dependency relation to the HEAD (root iff HEAD = 0) or a defined language-specific subtype of one. <br>
# DEPS: Enhanced dependency graph in the form of a list of head-deprel pairs. <br>
# MISC: Any other annotation.
#
# The fields DEPS and MISC replace the obsolete fields PHEAD and PDEPREL of the CoNLL-X format. In addition, we have modified the usage of the ID, FORM, LEMMA, XPOS, FEATS and HEAD fields as explained below.
#
# The fields must additionally meet the following constraints:
#
# Fields must not be empty.
# Fields other than FORM, LEMMA, and MISC must not contain space characters.
# Underscore (_) is used to denote unspecified values in all fields except ID. Note that no format-level distinction is made for the rare cases where the FORM or LEMMA is the literal underscore – processing in such cases is application-dependent. Further, in UD treebanks the UPOS, HEAD, and DEPREL columns are not allowed to be left unspecified except in multiword tokens, where all must be unspecified, and empty nodes, where UPOS is optional and HEAD and DEPREL must be unspecified. The enhanced DEPS annotation is optional in UD treebanks, but if it is provided, it must be provided for all sentences in the treebank. "
#
# *** taken from https://universaldependencies.org/format.html

# %%
conll_header = ['id', 'form', 'lemma', 'upos', 'xpos', 'feats', 'head', 'deprel', 'deps', 'misc']

# %%
# retrieve longest line
# -> required for the creation of the dataframe later
def retrieveLength(path_to_file):
    c = 0
    max_line_length = -1
    sentences = 0
    tokens = 0
    with open(path_to_file) as file:
        for line in file:


            if line.startswith('# text'):
                sentences += 1
            elif line.startswith('#') or line.startswith('\n'):
                pass
            else:
                values = line.split('\t')
                line_length = len(values)
                if line_length > max_line_length:
                    max_line_length = line_length

                tokens += 1

            c += 1   
    
    print(f'# Sentences in file: {sentences}')
    print(f'# Tokens in file: {tokens}')
    print(f'Maxium of columns in file: {max_line_length}')
    
    return max_line_length

# %%
# conversion into dataframe
def createDataFrame(path_to_file, sentence_limit=None):

    max_line_length = retrieveLength(path_to_file)
    sentences = 0

    # create empty dataframe with known columns and fillers for remaining collumns
    headers_df = np.full(max_line_length, np.str)
    headers_df[:len(conll_header)] = conll_header
    headers_df[len(conll_header):] = '_'
    df = pd.DataFrame(columns=headers_df)


    # loop through file
    with open(path_to_file) as file:
        for line in file:

            # pass all other lines
            if line.startswith('# text'):
                sentences += 1
                
            elif line.startswith('#') or line.startswith('\n'):
                pass
            
            # only go into token lines
            else:

                if line.endswith('\n'):
                    line = line.replace('\n', '')
                values = np.array(line.split('\t'))

                array  = np.full(max_line_length, np.str)
                array[:len(values)] = values
                array[len(values):] = '_'

                df_entry = pd.DataFrame(columns=headers_df, data=[array])

                df = pd.concat([df, df_entry], axis = 0, ignore_index=True)

            if type(sentence_limit) and sentences > sentence_limit:
                break
                
        print(f'\n ## {sentences-1} sentences were added to dataframe.')

    return df

# %%
# call function with path to file and a integer that set the limit of sentences to include
df = createDataFrame(path_example, 5)

df.head(40)
# Out:
# # Sentences in file: 5
# # Tokens in file: 46
# Maxium of columns in file: 14
#
#  ## 4 sentences were added to dataframe.
#     id           form          lemma   upos xpos  \
# 0    1         Really         really    ADV   RB
# 1    2        enjoyed          enjoy   VERB  VBD
# 2    3             it             it   PRON  PRP
# 3    4              .              .  PUNCT    .
# 4    1        Compare        compare   VERB  VBN
# 5    2             to             to    ADP   IN
# 6    3           last           last    ADJ   JJ
# 7    4         decade         decade   NOUN   NN
# 8    5           this           this    DET   DT
# 9    6     University     University  PROPN  NNP
# 10   7             is             be    AUX  VBZ
# 11   8        gaining           gain   VERB  VBG
# 12   9           more           more    ADJ  JJR
# 13  10       prestige       prestige   NOUN   NN
# 14  11             in             in    ADP   IN
# 15  12  International  international    ADJ   JJ
# 16  13          level          level   NOUN   NN
# 17   1             If             if  SCONJ   IN
# 18   2            you            you   PRON  PRP
# 19   3            're             be    AUX  VBP
# 20   4        looking           look   VERB  VBG
# 21   5            for            for    ADP   IN
# 22   6      homestyle      homestyle    ADJ   JJ
# 23   7       Japanese       japanese    ADJ   JJ
# 24   8           food           food   NOUN   NN
# 25   9              ,              ,  PUNCT    ,
# 26  10            you            you   PRON  PRP
# 27  11             ca            can    AUX   MD
# 28  12            n't            not   PART   RB
# 29  13           beat           beat   VERB   VB
# 30  14           this           this   PRON   DT
# 31   1             ok             ok   INTJ   UH
# 32   1             ca            can    AUX   MD
# 33   2            n't            not   PART   RB
# 34   3       remember       remember   VERB   VB
# 35   4           good           good    ADJ   JJ
# 36   5             or             or  CCONJ   CC
# 37   6            bad            bad    ADJ   JJ
# 38   7              ,              ,  PUNCT    ,
# 39   8             so             so    ADV   RB
#
#                                                 feats head  deprel  \
# 0                                                   _    2  advmod
# 1                    Mood=Ind|Tense=Past|VerbForm=Fin    0    root
# 2   Case=Nom|Gender=Neut|Number=Sing|Person=3|Pron...    2     obj
# 3                                                   _    2   punct
# 4                            Tense=Past|VerbForm=Part    8   advcl
# 5                                                   _    4    case
# 6                                          Degree=Pos    4    amod
# 7                                         Number=Sing    1     obl
# 8                            Number=Sing|PronType=Dem    6     det
# 9                                         Number=Sing    8   nsubj
# 10  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbF...    8     aux
# 11                                       VerbForm=Ger    0    root
# 12                                         Degree=Cmp   10    amod
# 13                                        Number=Sing    8     obj
# 14                                                  _   13    case
# 15                                         Degree=Pos   13    amod
# 16                                        Number=Sing    8     obl
# 17                                                  _    4    mark
# 18                     Case=Nom|Person=2|PronType=Prs    4   nsubj
# 19                   Mood=Ind|Tense=Pres|VerbForm=Fin    4     aux
# 20                                       VerbForm=Ger   13   advcl
# 21                                                  _    8    case
# 22                                         Degree=Pos    8    amod
# 23                                         Degree=Pos    8    amod
# 24                                        Number=Sing    4     obl
# 25                                                  _   13   punct
# 26                     Case=Nom|Person=2|PronType=Prs   13   nsubj
# 27                                       VerbForm=Fin   13     aux
# 28                                                  _   13  advmod
# 29                                       VerbForm=Inf    0    root
# 30                           Number=Sing|PronType=Dem   13     obj
# 31                                                  _    0    root
# 32                                       VerbForm=Fin    3     aux
# 33                                                  _    3  advmod
# 34                                       VerbForm=Inf    0    root
# 35                                         Degree=Pos    3   ccomp
# 36                                                  _    6      cc
# 37                                         Degree=Pos    4    conj
# 38                                                  _    3   punct
# 39                                                  _   13  advmod
#
#                  deps           misc            _         _     _         _
# 0            2:advmod              _            _  ARGM-EXT     _         _
# 1              0:root              _     enjoy.01         V     _         _
# 2               2:obj  SpaceAfter=No            _      ARG1     _         _
# 3             2:punct              _            _         _     _         _
# 4             8:advcl              _   compare.01         V     _  ARGM-ADV
# 5              4:case              _            _         _     _         _
# 6              4:amod              _            _         _     _         _
# 7            1:obl:to              _            _      ARG2     _         _
# 8               6:det              _            _         _     _         _
# 9             8:nsubj              _            _         _     _      ARG0
# 10              8:aux              _        be.03         _     V         _
# 11             0:root              _      gain.02         _     _         V
# 12            10:amod              _            _         _     _         _
# 13              8:obj              _            _         _     _      ARG1
# 14            13:case              _            _         _     _         _
# 15            13:amod              _            _         _     _         _
# 16           8:obl:in              _            _         _     _  ARGM-ADV
# 17             4:mark              _            _         _     _         _
# 18            4:nsubj  SpaceAfter=No            _         _  ARG0         _
# 19              4:aux              _        be.03         V     _         _
# 20        13:advcl:if              _      look.01         _     V  ARGM-ADV
# 21             8:case              _            _         _     _         _
# 22             8:amod              _            _         _     _         _
# 23             8:amod              _            _         _     _         _
# 24          4:obl:for  SpaceAfter=No            _         _  ARG1         _
# 25           13:punct              _            _         _     _         _
# 26           13:nsubj              _            _         _     _      ARG0
# 27             13:aux  SpaceAfter=No            _         _     _  ARGM-MOD
# 28          13:advmod              _            _         _     _  ARGM-NEG
# 29             0:root              _      beat.03         _     _         V
# 30             13:obj              _            _         _     _      ARG1
# 31             0:root              _            _               _         _
# 32              3:aux  SpaceAfter=No            _  ARGM-MOD     _         _
# 33           3:advmod              _            _  ARGM-NEG     _         _
# 34             0:root              _  remember.01         V     _         _
# 35            3:ccomp              _            _      ARG2     _         _
# 36               6:cc              _            _         _     _         _
# 37  3:ccomp|4:conj:or  SpaceAfter=No            _         _     _         _
# 38            3:punct              _            _         _     _         _
# 39          13:advmod              _            _         _     _  ARGM-ADV

# %%
# %%time
# call function with path to file and a integer that set the limit of sentences to include
df = createDataFrame(path_train, 100)

df.iloc[:,0:20].head(40)
# Out:
# # Sentences in file: 12530
# # Tokens in file: 204235
# Maxium of columns in file: 46
#
#  ## 100 sentences were added to dataframe.
# CPU times: user 14.3 s, sys: 197 ms, total: 14.5 s
# Wall time: 14.7 s
#     id       form      lemma   upos   xpos  \
# 0    1         Al         Al  PROPN    NNP
# 1    2          -          -  PUNCT   HYPH
# 2    3      Zaman      Zaman  PROPN    NNP
# 3    4          :          :  PUNCT      :
# 4    5   American   american    ADJ     JJ
# 5    6     forces      force   NOUN    NNS
# 6    7     killed       kill   VERB    VBD
# 7    8     Shaikh     Shaikh  PROPN    NNP
# 8    9   Abdullah   Abdullah  PROPN    NNP
# 9   10         al         al  PROPN    NNP
# 10  11          -          -  PUNCT   HYPH
# 11  12        Ani        Ani  PROPN    NNP
# 12  13          ,          ,  PUNCT      ,
# 13  14        the        the    DET     DT
# 14  15   preacher   preacher   NOUN     NN
# 15  16         at         at    ADP     IN
# 16  17        the        the    DET     DT
# 17  18     mosque     mosque   NOUN     NN
# 18  19         in         in    ADP     IN
# 19  20        the        the    DET     DT
# 20  21       town       town   NOUN     NN
# 21  22         of         of    ADP     IN
# 22  23       Qaim       Qaim  PROPN    NNP
# 23  24          ,          ,  PUNCT      ,
# 24  25       near       near    ADP     IN
# 25  26        the        the    DET     DT
# 26  27     Syrian     syrian    ADJ     JJ
# 27  28     border     border   NOUN     NN
# 28  29          .          .  PUNCT      .
# 29   1          [          [  PUNCT  -LRB-
# 30   2       This       this    DET     DT
# 31   3    killing    killing   NOUN     NN
# 32   4         of         of    ADP     IN
# 33   5          a          a    DET     DT
# 34   6  respected  respected    ADJ     JJ
# 35   7     cleric     cleric   NOUN     NN
# 36   8       will       will    AUX     MD
# 37   9         be         be    AUX     VB
# 38  10    causing      cause   VERB    VBG
# 39  11         us         we   PRON    PRP
#
#                                          feats head     deprel          deps  \
# 0                                  Number=Sing    0       root        0:root
# 1                                            _    1      punct       1:punct
# 2                                  Number=Sing    1       flat        1:flat
# 3                                            _    1      punct       1:punct
# 4                                   Degree=Pos    6       amod        6:amod
# 5                                  Number=Plur    7      nsubj       7:nsubj
# 6             Mood=Ind|Tense=Past|VerbForm=Fin    1  parataxis   1:parataxis
# 7                                  Number=Sing    7        obj         7:obj
# 8                                  Number=Sing    8       flat        8:flat
# 9                                  Number=Sing    8       flat        8:flat
# 10                                           _    8      punct       8:punct
# 11                                 Number=Sing    8       flat        8:flat
# 12                                           _    8      punct       8:punct
# 13                   Definite=Def|PronType=Art   15        det        15:det
# 14                                 Number=Sing    8      appos       8:appos
# 15                                           _   18       case       18:case
# 16                   Definite=Def|PronType=Art   18        det        18:det
# 17                                 Number=Sing    7        obl      7:obl:at
# 18                                           _   21       case       21:case
# 19                   Definite=Def|PronType=Art   21        det        21:det
# 20                                 Number=Sing   18       nmod    18:nmod:in
# 21                                           _   23       case       23:case
